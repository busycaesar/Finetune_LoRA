# %% [markdown]
# <a href="https://colab.research.google.com/github/busycaesar/Finetune_LoRA/blob/Master/gemma-adaptor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

# Note: `userdata.get` is a Colab API. If you're not using Colab, set the env
# vars as appropriate for your system.
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')
os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')

# %%
# %pip install -U -q keras-hub keras

# %%
os.environ["KERAS_BACKEND"] = "jax"  # Or "torch" or "tensorflow".
# Avoid memory fragmentation on JAX backend.
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"]="1.00"

# %%
import keras
import keras_hub

# %%
gemma_lm = keras_hub.models.Gemma3CausalLM.from_preset("gemma3_instruct_1b")

# %%
template = "Instruction:\n{instruction}\n\nResponse:\n{response}"

# %%
prompt = template.format(
    instruction="What should I do on a trip to Europe?",
    response="",
)

print(gemma_lm.generate(prompt, max_length=256))

# %%
from huggingface_hub import hf_hub_download

weights_path = hf_hub_download(
  repo_id="busycaesar/gemma3-lora",
  filename="lora_weights.lora.h5"
)

# %%
gemma_lm.backbone.enable_lora(rank=4)

# %%
gemma_lm.backbone.load_lora_weights(weights_path)

# %%
prompt = template.format(
    instruction="What should I do on a trip to Europe?",
    response="",
)

print(gemma_lm.generate(prompt, max_length=256))
